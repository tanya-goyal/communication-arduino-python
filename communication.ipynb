# %%
import serial
if __name__ == '__main__':
    ser = serial.Serial('com11',9600)
    ser.flush()
    while True:
        if ser.in_waiting > 0:
            
            
            ser.write(b"F\n")
            line1 = ser.readline().decode('utf-8').rstrip()
            print(line1)
# Out:
# hi from arduino!!
# You sent me: front
# You sent me: front
# You sent me: front
# You sent me: front
# You sent me: front
# You sent me: front
# You sent me: front
# You sent me: front
# You sent me: front
# You sent me: front
# You sent me: front
# You sent me: front
# You sent me: front
# You sent me: front
# You sent me: front
# You sent me: front
# You sent me: front
# You sent me: front
# You sent me: front
# You sent me: front
# You sent me: front
# You sent me: front
# You sent me: front
# You sent me: front
# You sent me: front
# You sent me: front
# You sent me: front
# You sent me: front
# You sent me: front
# You sent me: front
# You sent me: front
# You sent me: front
# You sent me: front
# You sent me: front
# You sent me: front
# You sent me: front
# You sent me: front
# You sent me: front
# You sent me: front
# You sent me: front
# You sent me: front
# You sent me: front
# You sent me: front
# You sent me: front
# You sent me: front
# You sent me: front
# ...
